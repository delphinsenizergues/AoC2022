# %%
#recuperer le fichier sous forme de liste
liste_coup=[]
for line in open("input2.txt").readlines():
    
    liste_coup.append(str(line))
liste_coup
# Out:
# ['B Y\n',
#  'A X\n',
#  'C Z\n',
#  'A Z\n',
#  'B Y\n',
#  'B Y\n',
#  'A X\n',
#  'C Z\n',
#  'B Y\n',
#  'B Y\n',
#  'C Z\n',
#  'C X\n',
#  'B Y\n',
#  'C Z\n',
#  'B Y\n',
#  'C Z\n',
#  'A Z\n',
#  'A Z\n',
#  'A X\n',
#  'B Y\n',
#  'A X\n',
#  'C Z\n',
#  'C Y\n',
#  'C Z\n',
#  'C Z\n',
#  'C Z\n',
#  'A X\n',
#  'A X\n',
#  'B Y\n',
#  'A Z\n',
#  'B Z\n',
#  'B Y\n',
#  'A X\n',
#  'A X\n',
#  'C Z\n',
#  'B Y\n',
#  'B Y\n',
#  'B Z\n',
#  'A Z\n',
#  'A X\n',
#  'C Z\n',
#  'B Z\n',
#  'A Z\n',
#  'C Z\n',
#  'C Z\n',
#  'C Z\n',
#  'C Z\n',
#  'C Z\n',
#  'C Z\n',
#  'B X\n',
#  'A Z\n',
#  'A Z\n',
#  'C Z\n',
#  'C Z\n',
#  'C Z\n',
#  'A Y\n',
#  'C Z\n',
#  'B Y\n',
#  'C Z\n',
#  'C Z\n',
#  'C Z\n',
#  'B Y\n',
#  'B Z\n',
#  'A X\n',
#  'A X\n',
#  'C Z\n',
#  'B Y\n',
#  'B Y\n',
#  'B Z\n',
#  'A X\n',
#  'A X\n',
#  'C Z\n',
#  'B Y\n',
#  'C Z\n',
#  'A X\n',
#  'C Z\n',
#  'A X\n',
#  'C X\n',
#  'A Y\n',
#  'A Y\n',
#  'B Y\n',
#  'A Y\n',
#  'C Z\n',
# ...
